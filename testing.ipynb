# %%
import random

import wandb

# Start a new wandb run to track this script.
run = wandb.init(
    # Set the wandb entity where your project will be logged (generally your team name).
    entity="da24m023-indian-institute-of-technology-madras",
    # Set the wandb project where this run will be logged.
    project="testing",
    # Track hyperparameters and run metadata.
    config={
        "learning_rate": 0.02,
        "architecture": "CNN",
        "dataset": "CIFAR-100",
        "epochs": 10,
    },
)

# Simulate training.
epochs = 10
offset = random.random() / 5
for epoch in range(2, epochs):
    acc = 1 - 2**-epoch - random.random() / epoch - offset
    loss = 2**-epoch + random.random() / epoch + offset

    # Log metrics to wandb.
    run.log({"acc": acc, "loss": loss})

# Finish the run and upload any remaining data.
run.finish()
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\asyncio\tasks.py:500, in wait_for(fut, timeout)
#     499 try:
# --> 500     return fut.result()
#     501 except exceptions.CancelledError as exc:
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\asyncio\locks.py:213, in Event.wait(self)
#     212 try:
# --> 213     await fut
#     214     return True
#
# CancelledError:
#
# The above exception was the direct cause of the following exception:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\mailbox\handles.py:141, in MailboxHandle.wait_async(self, timeout)
#     140 try:
# --> 141     await asyncio.wait_for(evt.wait(), timeout=timeout)
#     143 except (asyncio.TimeoutError, TimeoutError) as e:
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\asyncio\tasks.py:502, in wait_for(fut, timeout)
#     501         except exceptions.CancelledError as exc:
# --> 502             raise exceptions.TimeoutError() from exc
#     503 finally:
#
# TimeoutError:
#
# The above exception was the direct cause of the following exception:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_init.py:946, in _WandbInit.init(self, settings, config)
#     945 try:
# --> 946     result = wait_with_progress(
#     947         run_init_handle,
#     948         timeout=timeout,
#     949         progress_after=1,
#     950         display_progress=display_init_message,
#     951     )
#     953 except TimeoutError:
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\mailbox\wait_with_progress.py:23, in wait_with_progress(handle, timeout, progress_after, display_progress)
#      19 """Wait for a handle, possibly displaying progress to the user.
#      20
#      21 Equivalent to passing a single handle to `wait_all_with_progress`.
#      22 """
# ---> 23 return wait_all_with_progress(
#      24     [handle],
#      25     timeout=timeout,
#      26     progress_after=progress_after,
#      27     display_progress=display_progress,
#      28 )[0]
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\mailbox\wait_with_progress.py:86, in wait_all_with_progress(handle_list, timeout, progress_after, display_progress)
#      81         return await _wait_handles_async(
#      82             handle_list,
#      83             timeout=remaining_timeout,
#      84         )
# ---> 86 return asyncio_compat.run(progress_loop_with_timeout)
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\lib\asyncio_compat.py:30, in run(fn)
#      29 try:
# ---> 30     return future.result()
#      32 finally:
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\lib\asyncio_compat.py:74, in _Runner.run(self, fn)
#      66 """Run a coroutine in asyncio, cancelling it on `cancel()`.
#      67
#      68 Returns:
#    (...)
#      72     _RunnerCancelledError: If `cancel()` is called.
#      73 """
# ---> 74 return asyncio.run(self._run_or_cancel(fn))
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\asyncio\runners.py:190, in run(main, debug)
#     189 with Runner(debug=debug) as runner:
# --> 190     return runner.run(main)
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\asyncio\runners.py:118, in Runner.run(self, coro, context)
#     117 try:
# --> 118     return self._loop.run_until_complete(task)
#     119 except exceptions.CancelledError:
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py:654, in BaseEventLoop.run_until_complete(self, future)
#     652     raise RuntimeError('Event loop stopped before Future completed.')
# --> 654 return future.result()
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\lib\asyncio_compat.py:98, in _Runner._run_or_cancel(self, fn)
#      97 if fn_task.done():
# ---> 98     return fn_task.result()
#      99 else:
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\mailbox\wait_with_progress.py:81, in wait_all_with_progress.<locals>.progress_loop_with_timeout()
#      79     remaining_timeout = None
# ---> 81 return await _wait_handles_async(
#      82     handle_list,
#      83     timeout=remaining_timeout,
#      84 )
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\mailbox\wait_with_progress.py:129, in _wait_handles_async(handle_list, timeout)
#     127     results[index] = await handle.wait_async(timeout=timeout)
# --> 129 async with asyncio_compat.open_task_group() as task_group:
#     130     for index in range(len(handle_list)):
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:217, in _AsyncGeneratorContextManager.__aexit__(self, typ, value, traceback)
#     216 try:
# --> 217     await anext(self.gen)
#     218 except StopAsyncIteration:
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\lib\asyncio_compat.py:190, in open_task_group()
#     189     yield task_group
# --> 190     await task_group._wait_all()
#     191 finally:
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\lib\asyncio_compat.py:159, in TaskGroup._wait_all(self)
#     158     if exc := task.exception():
# --> 159         raise exc
#     160 except asyncio.CancelledError:
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\mailbox\wait_with_progress.py:127, in _wait_handles_async.<locals>.wait_single(index)
#     126 handle = handle_list[index]
# --> 127 results[index] = await handle.wait_async(timeout=timeout)
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\mailbox\handles.py:150, in MailboxHandle.wait_async(self, timeout)
#     149         else:
# --> 150             raise TimeoutError(
#     151                 f"Timed out waiting for response on {self._address}"
#     152             ) from e
#     154 else:
#
# TimeoutError: Timed out waiting for response on zpok9hccyg52
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3 import wandb
#       5 # Start a new wandb run to track this script.
# ----> 6 run = wandb.init(
#       7     # Set the wandb entity where your project will be logged (generally your team name).
#       8     entity="da24m023-indian-institute-of-technology-madras",
#       9     # Set the wandb project where this run will be logged.
#      10     project="testing",
#      11     # Track hyperparameters and run metadata.
#      12     config={
#      13         "learning_rate": 0.02,
#      14         "architecture": "CNN",
#      15         "dataset": "CIFAR-100",
#      16         "epochs": 10,
#      17     },
#      18 )
#      20 # Simulate training.
#      21 epochs = 10
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_init.py:1485, in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, anonymous, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings)
#    1481     wl._get_logger().exception("error in wandb.init()", exc_info=e)
#    1483 # Need to build delay into this sentry capture because our exit hooks
#    1484 # mess with sentry's ability to send out errors before the program ends.
# -> 1485 wandb._sentry.reraise(e)
#    1486 raise AssertionError()
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\analytics\sentry.py:156, in Sentry.reraise(self, exc)
#     153 self.exception(exc)
#     154 # this will messily add this "reraise" function to the stack trace,
#     155 # but hopefully it's not too bad
# --> 156 raise exc.with_traceback(sys.exc_info()[2])
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_init.py:1471, in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, anonymous, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings)
#    1468         _monkeypatch_tensorboard()
#    1469         init_telemetry.feature.tensorboard_sync = True
# -> 1471     return wi.init(run_settings, run_config)
#    1473 except KeyboardInterrupt as e:
#    1474     if wl:
#
# File c:\Users\sudha\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_init.py:959, in _WandbInit.init(self, settings, config)
#     954     run_init_handle.cancel(backend.interface)
#     956     # This may either be an issue with the W&B server (a CommError)
#     957     # or a bug in the SDK (an Error). We cannot distinguish between
#     958     # the two causes here.
# --> 959     raise CommError(
#     960         f"Run initialization has timed out after {timeout} sec."
#     961         " Please try increasing the timeout with the `init_timeout`"
#     962         " setting: `wandb.init(settings=wandb.Settings(init_timeout=120))`."
#     963     )
#     965 assert result.run_result
#     967 if error := ProtobufErrorHandler.to_exception(result.run_result.error):
#
# CommError: Run initialization has timed out after 90.0 sec. Please try increasing the timeout with the `init_timeout` setting: `wandb.init(settings=wandb.Settings(init_timeout=120))`.
